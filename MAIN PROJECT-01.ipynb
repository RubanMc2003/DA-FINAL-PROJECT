# %% [markdown]
# # Project Title
#
# MERCEDES BENZ CLASA E

# %% [markdown]
# # Domain
#
# MANUFACTORING

# %% [markdown]
# # Objective
#
# 1. To identify meaningful patterns, trends, and insights from the dataset using exploratory data analysis (EDA)
#
# 2. To clean, transform, and preprocess the data for analysis
#
# 3. To create meaningful visualizations that clearly explain the story behind the data
#
# 4. To provide actionable insights and recommendations from the analysis

# %% [markdown]
# # Outcome
#
# The project helps uncover key patterns, trends, and hidden insights from the dataset. The analysis provides a clear understanding of the data and supports decision-making with evidence-based findings.

# %% [markdown]
# #**Dataset Information**
#
# **Source:**  Company Internal Dataset
#
# **Year / Timeline:** Data collected during 2024
#
# **Dataset Column Description:**
#
# brand_name- Mercedes Benz
#
# model - Model name of the car.
#
# price - Market price pf the car.
#
# avg_rating - Average user rating of the car.
#
# car_brand - Brand or manufacturer of the car.
#
# car_speed - Car speed of the measure in KM
#
# fuel_capacity - fuel capacity of the car in fuel tank.
#
# screen_size - Display size of the car measured in inches.
#
# car_rate - brand rate of the car in inr
#
# num_rear_cameras - Total number of rear cameras on the car.

# %% [markdown]
# # **Note For Kind of Analysis to be done**
#
# **Type of Analysis**
#
# * Descriptive Analysis (summarizing the dataset)
#
# * Diagnostic Analysis (finding reasons behind patterns)
#
# * Predictive Analysis (optional if forecasting required using basic stats)
#
# * Prescriptive Analysis (recommendations for business decisions)

# %% [markdown]
# # Stages for DA Project

# %% [markdown]
# ## Stage 1 – Problem Definition and Dataset Selection
#
# Define the business problem and expected outcome
#
# Choose dataset and explain its source, size, and features
#
# Import libraries, load dataset
#
# Dataset description (rows, columns, features)
#
# Initial EDA (head, info, describe, shape, null checks, duplicate check)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("https://raw.githubusercontent.com/RubanMc2003/DA-FINAL-PROJECT/refs/heads/main/Mercedes-Benz_Clasa-E_dataset.csv")
df
# Out:
#          brand_name model_name         id  external_ad_id  vin  \
# 0     MERCEDES-BENZ    Clasa E   440741.0    1.995899e+08  NaN
# 1     MERCEDES-BENZ    Clasa E   950052.0    2.165910e+08  NaN
# 2     MERCEDES-BENZ    Clasa E   788024.0    2.093913e+08  NaN
# 3     MERCEDES-BENZ    Clasa E   440859.0    1.982032e+08  NaN
# 4     MERCEDES-BENZ    Clasa E   632774.0    2.087671e+08  NaN
# ...             ...        ...        ...             ...  ...
# 6443  MERCEDES-BENZ    Clasa E  1328769.0    7.046760e+09  NaN
# 6444  MERCEDES-BENZ    Clasa E  1330829.0    7.046776e+09  NaN
# 6445  MERCEDES-BENZ    Clasa E  1339062.0    7.046828e+09  NaN
# 6446  MERCEDES-BENZ    Clasa E  1340888.0    7.046835e+09  NaN
# 6447  MERCEDES-BENZ    Clasa E  1352026.0    7.046946e+09  NaN
#
#                                                     url   source county_id  \
# 0     https://www.olx.ro/oferta/mercedes-e-classe-20...      olx        42
# ...

# %%
df.columns
# Out:
# Index(['brand_name', 'model_name', 'id', 'external_ad_id', 'vin', 'url',
#        'source', 'county_id', 'city_id', 'area', 'zipcode', 'category', 'body',
#        'vehicle_condition', 'brand_id', 'model_id', 'km', 'cmc', 'year',
#        'fuel', 'fuel_consumption', 'power_hp', 'power_kw', 'gearbox', 'color',
#        'color_id', 'doors', 'seats', 'emission_class', 'register_date',
#        'owner_id', 'euro_price', 'price_type', 'currency', 'other_details',
#        'description', 'title', 'promoted', 'dealer', 'negotiable', 'coords',
#        'is_active', 'publish_date', 'sell_date', 'updated_at_date',
#        'created_at', 'updated_at', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49',
#        'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53',
#        'Unnamed: 54'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  id  external_ad_id  brand_id  model_id            km  \
# count  6.447000e+03    6.447000e+03    6446.0    6446.0  6.446000e+03
# mean   7.505226e+05    1.210599e+09     217.0      19.0  1.692403e+09
# std    3.438552e+05    2.452892e+09       0.0       0.0  2.609397e+10
# min    1.000000e+00    1.000000e+00     217.0      19.0  0.000000e+00
# 25%    4.758435e+05    1.973156e+08     217.0      19.0  1.396250e+05
# 50%    7.502700e+05    2.125337e+08     217.0      19.0  2.000000e+05
# 75%    1.040540e+06    2.249890e+08     217.0      19.0  2.500000e+05
# max    1.357794e+06    7.046946e+09     217.0      19.0  4.040000e+11
#
#                cmc         year  fuel_consumption       power_hp  \
# count  6446.000000  6446.000000               0.0    6442.000000
# mean   2360.293205  2013.301738               NaN     310.150419
# std     594.413735     2.787429               NaN   11219.499715
# min       0.000000  2010.000000               NaN       0.000000
# ...

# %% [markdown]
# ## Stage 2 – Data Cleaning and Pre-processing
#
# Handle missing values (impute or drop)
#
# Handle duplicates
#
# Treat outliers if required
#
# Check skewness and apply transformations
#
# Convert data types if needed
#
# Feature transformations (date parts, derived fields if required for analysis)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6448 entries, 0 to 6447
# Data columns (total 55 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand_name         6447 non-null   object
#  1   model_name         6447 non-null   object
#  2   id                 6447 non-null   float64
#  3   external_ad_id     6447 non-null   float64
#  4   vin                500 non-null    object
#  5   url                6447 non-null   object
#  6   source             6447 non-null   object
#  7   county_id          6447 non-null   object
#  8   city_id            6447 non-null   object
#  9   area               873 non-null    object
#  10  zipcode            6447 non-null   object
#  11  category           1 non-null      object
#  12  body               6431 non-null   object
#  13  vehicle_condition  6446 non-null   object
#  14  brand_id           6446 non-null   float64
#  15  model_id           6446 non-null   float64
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6443    False
# 6444    False
# 6445    False
# 6446    False
# 6447    False
# Length: 6448, dtype: bool

# %%
df.shape
# Out:
# (6448, 55)

# %%
rows, columns = df.shape
print("Rows:", rows)
print("Columns:", columns)
# Out:
# Rows: 6448
# Columns: 55

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# brand_name              1
# model_name              1
# id                      1
# external_ad_id          1
# vin                  5948
# url                     1
# source                  1
# county_id               1
# city_id                 1
# area                 5575
# zipcode                 1
# category             6447
# body                   17
# vehicle_condition       2
# brand_id                2
# model_id                2
# km                      2
# cmc                     2
# year                    2
# fuel                  123
# fuel_consumption     6448
# power_hp                6
# power_kw               10
# gearbox               868
# color                 727
# color_id                2
# doors                  13
# seats                  40
# emission_class         11
# register_date        6448
# owner_id                2
# euro_price              3
# price_type           6448
# currency                2
# other_details        6448
# ...

# %% [markdown]
# ### Analys abaout the sales by region

# %%
df.drop(['Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49',
       'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53',
       'Unnamed: 54'],
            axis=1,inplace=True
 )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6448 entries, 0 to 6447
# Data columns (total 47 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand_name         6447 non-null   object
#  1   model_name         6447 non-null   object
#  2   id                 6447 non-null   float64
#  3   external_ad_id     6447 non-null   float64
#  4   vin                500 non-null    object
#  5   url                6447 non-null   object
#  6   source             6447 non-null   object
#  7   county_id          6447 non-null   object
#  8   city_id            6447 non-null   object
#  9   area               873 non-null    object
#  10  zipcode            6447 non-null   object
#  11  category           1 non-null      object
#  12  body               6431 non-null   object
#  13  vehicle_condition  6446 non-null   object
#  14  brand_id           6446 non-null   float64
#  15  model_id           6446 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['brand_name', 'model_name', 'id', 'external_ad_id', 'url', 'source',
#        'county_id', 'city_id', 'area', 'zipcode', 'category', 'body',
#        'vehicle_condition', 'brand_id', 'model_id', 'km', 'cmc', 'year',
#        'fuel', 'fuel_consumption', 'power_hp', 'power_kw', 'gearbox', 'color',
#        'color_id', 'doors', 'seats', 'emission_class', 'register_date',
#        'owner_id', 'euro_price', 'price_type', 'currency', 'other_details',
#        'description', 'title', 'promoted', 'dealer', 'negotiable', 'coords',
#        'is_active', 'publish_date', 'sell_date', 'updated_at_date',
#        'created_at', 'updated_at'],
#       dtype='object')

# %%
rows, columns = df.shape
print("Rows:", rows)
print("Columns:", columns)
# Out:
# Rows: 6448
# Columns: 46

# %%
df
# Out:
#          brand_name model_name         id  external_ad_id  \
# 0     MERCEDES-BENZ    Clasa E   440741.0    1.995899e+08
# 1     MERCEDES-BENZ    Clasa E   950052.0    2.165910e+08
# 2     MERCEDES-BENZ    Clasa E   788024.0    2.093913e+08
# 3     MERCEDES-BENZ    Clasa E   440859.0    1.982032e+08
# 4     MERCEDES-BENZ    Clasa E   632774.0    2.087671e+08
# ...             ...        ...        ...             ...
# 6443  MERCEDES-BENZ    Clasa E  1328769.0    7.046760e+09
# 6444  MERCEDES-BENZ    Clasa E  1330829.0    7.046776e+09
# 6445  MERCEDES-BENZ    Clasa E  1339062.0    7.046828e+09
# 6446  MERCEDES-BENZ    Clasa E  1340888.0    7.046835e+09
# 6447  MERCEDES-BENZ    Clasa E  1352026.0    7.046946e+09
#
#                                                     url   source county_id  \
# 0     https://www.olx.ro/oferta/mercedes-e-classe-20...      olx        42
# 1     https://www.olx.ro/d/oferta/mercedes-e350-coup...      olx         9
# ...

# %%
date_cols = ['publish_date', 'sell_date', 'updated_at_date']

for col in date_cols:
    if col in df.columns:
        df[col].fillna(method='ffill', inplace=True)
# Out:
# /tmp/ipython-input-1887513868.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(method='ffill', inplace=True)
# /tmp/ipython-input-1887513868.py:5: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[col].fillna(method='ffill', inplace=True)

# %%
categorical_cols = df.select_dtypes(include=['object']).columns

for col in categorical_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-1607249780.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)

# %%
df.euro_price
# Out:
# 0        5500.0
# 1        9400.0
# 2        8099.0
# 3        7500.0
# 4       11000.0
#          ...
# 6443    17950.0
# 6444    11999.0
# 6445    37000.0
# 6446    29999.0
# 6447    41900.0
# Name: euro_price, Length: 6448, dtype: float64

# %%
df.price_type
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 6443   NaN
# 6444   NaN
# 6445   NaN
# 6446   NaN
# 6447   NaN
# Name: price_type, Length: 6448, dtype: float64

# %%
df['price_type'] = df['price_type'].fillna('unknown')

# %%
df.price_type
# Out:
# 0       unknown
# 1       unknown
# 2       unknown
# 3       unknown
# 4       unknown
#          ...
# 6443    unknown
# 6444    unknown
# 6445    unknown
# 6446    unknown
# 6447    unknown
# Name: price_type, Length: 6448, dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of          brand_name model_name         id  external_ad_id  \
# 0     MERCEDES-BENZ    Clasa E   440741.0    1.995899e+08
# 1     MERCEDES-BENZ    Clasa E   950052.0    2.165910e+08
# 2     MERCEDES-BENZ    Clasa E   788024.0    2.093913e+08
# 3     MERCEDES-BENZ    Clasa E   440859.0    1.982032e+08
# 4     MERCEDES-BENZ    Clasa E   632774.0    2.087671e+08
# ...             ...        ...        ...             ...
# 6443  MERCEDES-BENZ    Clasa E  1328769.0    7.046760e+09
# 6444  MERCEDES-BENZ    Clasa E  1330829.0    7.046776e+09
# 6445  MERCEDES-BENZ    Clasa E  1339062.0    7.046828e+09
# 6446  MERCEDES-BENZ    Clasa E  1340888.0    7.046835e+09
# 6447  MERCEDES-BENZ    Clasa E  1352026.0    7.046946e+09
#
#                                                     url   source county_id  \
# 0     https://www.olx.ro/oferta/mercedes-e-classe-20...      olx        42
# 1     https://www.olx.ro/d/oferta/mercedes-e350-coup...      olx         9
# ...

# %%
df[df['seats'].isnull()]
# Out:
#                                            brand_name       model_name  \
# 319                                     MERCEDES-BENZ          Clasa E
# 564                                     MERCEDES-BENZ          Clasa E
# 1603                                    MERCEDES-BENZ          Clasa E
# 2236                                    MERCEDES-BENZ          Clasa E
# 2682                                    MERCEDES-BENZ          Clasa E
# 3176                                    MERCEDES-BENZ          Clasa E
# 3278                                    MERCEDES-BENZ          Clasa E
# 4759                                    MERCEDES-BENZ          Clasa E
# 4780                                    MERCEDES-BENZ          Clasa E
# 5170                                    MERCEDES-BENZ          Clasa E
# 5212                                    MERCEDES-BENZ          Clasa E
# 5213  Pret pentru finantare : 22.990 Euro Tva inclus"  Mercedes-Benz E
# ...

# %%
df.loc[(df['price_type'].isnull()) & (df['euro_price'] < 20000), 'price_type'] = 'Low'
df.loc[(df['price_type'].isnull()) & (df['euro_price'] >= 20000), 'price_type'] = 'High'

# %%
df[df['price_type'].notnull()][['euro_price', 'price_type']].sample(10)
# Out:
#       euro_price price_type
# 4945     12900.0    unknown
# 3574     15900.0    unknown
# 2727      9000.0    unknown
# 5589     21490.0    unknown
# 3532     16500.0    unknown
# 300      52000.0    unknown
# 3500      7700.0    unknown
# 2635     10500.0    unknown
# 2849      1600.0    unknown
# 99       10000.0    unknown

# %%
pd.crosstab(df['price_type'], df['euro_price'] < 20000)
# Out:
# euro_price  False  True
# price_type
# unknown      1479   4969

# %%
df['price_type'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['price_type'].value_counts()
# Out:
# price_type
# unknown    6448
# Name: count, dtype: int64

# %%
df['vin'].fillna('Unknown',inplace=True)
# Out:
# /tmp/ipython-input-1126173674.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['vin'].fillna('Unknown',inplace=True)

# %%
df
# Out:
#          brand_name model_name         id  external_ad_id      vin  \
# 0     MERCEDES-BENZ    Clasa E   440741.0    1.995899e+08  Unknown
# 1     MERCEDES-BENZ    Clasa E   950052.0    2.165910e+08  Unknown
# 2     MERCEDES-BENZ    Clasa E   788024.0    2.093913e+08  Unknown
# 3     MERCEDES-BENZ    Clasa E   440859.0    1.982032e+08  Unknown
# 4     MERCEDES-BENZ    Clasa E   632774.0    2.087671e+08  Unknown
# ...             ...        ...        ...             ...      ...
# 6443  MERCEDES-BENZ    Clasa E  1328769.0    7.046760e+09  Unknown
# 6444  MERCEDES-BENZ    Clasa E  1330829.0    7.046776e+09  Unknown
# 6445  MERCEDES-BENZ    Clasa E  1339062.0    7.046828e+09  Unknown
# 6446  MERCEDES-BENZ    Clasa E  1340888.0    7.046835e+09  Unknown
# 6447  MERCEDES-BENZ    Clasa E  1352026.0    7.046946e+09  Unknown
#
#                                                     url   source county_id  \
# 0     https://www.olx.ro/oferta/mercedes-e-classe-20...      olx        42
# ...

# %%
df[df['price_type'].isin(['Low', 'High'])][['euro_price', 'price_type']].head(10)
# Out:
# Empty DataFrame
# Columns: [euro_price, price_type]
# Index: []

# %%
def euro_price(price):
  if price <= 5500:
    return 'Excellent (Low price)'
  elif price <= 9500:
    return 'Good (Medium price)'
  else:
    return 'poor (High price)'

# %%
def year(year):
  if year < 2013:
    return ("low price")
  elif year < 2017:
    return ("Medium price")
  else:
    return ("High price")

# %%
if 'vin' in df.columns:
    if (df['vin'] == 'Unknown').any():
        print("YES")
    else:
        print("NO")
else:
    print("Column 'vin' not found in DataFrame.")
# Out:
# Column 'vin' not found in DataFrame.

# %%
df[['county_id','city_id','zipcode','brand_id','model_id']].tail()
# Out:
#      county_id city_id zipcode  brand_id  model_id
# 6443         9    2715       0     217.0      19.0
# 6444         1       1       0     217.0      19.0
# 6445        19    5237       0     217.0      19.0
# 6446         9    2715       0     217.0      19.0
# 6447        18    5226       0     217.0      19.0

# %%
result = (
    df[df["fuel"] == "Diesel"]
    .query("year > 2017")
    ["euro_price"]
    .mean()
)

# %%
avg_km_per_year = df.groupby("year")["km"].mean()

# %%
cars_per_year = df.groupby("year")["id"].count()

# %%
df["euro_price"].mean()
# Out:
# np.float64(16926.285492629944)

# %%
df["city_id"].head()
# Out:
# 0    13361
# 1     2715
# 2     2715
# 3     2200
# 4     7657
# Name: city_id, dtype: object

# %% [markdown]
# ## Stage 3 – EDA and Visualizations
#
# Univariate Analysis → distribution of single variables (countplot, histogram, boxplot)
#
# Bivariate Analysis → relation between two variables (scatterplot, barplot, correlation heatmap)
#
# Multivariate Analysis → relation among 3+ variables (pairplot, grouped analysis, pivot tables, advanced plots)
#
# Interpretation MUST with every visualization
#
# Focus on business story not just charts
#
# Each chart must be in seperate cells.

# %%
import pandas as pd
power_hp = df['power_kw'].value_counts()
print(power_hp)
# Out:
# power_kw
# 103.0    845
# 100.0    696
# 127.0    644
# 145.0    585
# 139.0    546
#         ...
# 51.0       1
# 23.0       1
# 214.0      1
# 236.0      1
# 156.0      1
# Name: count, Length: 138, dtype: int64

# %% [markdown]
# Insights
#
# * point by point insight should be recorded

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(df["power_kw"])
plt.xlabel("power_kw")
plt.ylabel("frequency")
plt.title("Histogram of power_kw")
plt.show()

# %% [markdown]
# Insights
#
#
# 1.The bar chart display the scatter plot of power_kw with fuel
#
# 2.The visualization was built with the help of Matplotlib in python with various labels,of frequency scale for easy to interpretation
#
# 3. Most power values are very small and concentrated on the left side of the histogram.
#
# 4 A few extremely large values exist and stretch the scale.
#
#
# 5.The distribution is strongly right-skewed, so outliers hide patterns in the typical data.

# %%
plt.figure(figsize=(10,4))
sns.countplot(data=df, x='brand_name')
plt.xticks(rotation=40)
plt.title('Brand name count')
plt.show()

# %% [markdown]
# Insights
#
#
# 1.It shows how many times each brand_name appears in the dataset, one brand (e.g., MERCEDES-BENZ)
#
# 2.It uses the brand_name column and a count plot to measure frequency.
#
# 3.showing which brands are most common and how unevenly the data is distributed across brands.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

plt.figure(figsize=(6,4))
sns.boxplot(y=df['euro_price'])
plt.title('Price Distribution')
plt.show()

# %% [markdown]
# Insights
#
#
# 1.It shows the distribution of car prices, where most prices are low and a few very high prices appear as outliers
#
# 2.It uses the euro_price column and a box plot to show spread and outliers.
#
# 3.We are showing price variation and identifying unusually expensive cars in the data.

# %%
plt.figure(figsize=(6,4))
df['source'].value_counts().plot(kind='bar')
plt.title('Source Count')
plt.xlabel('Source')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Insights
#
#
# 1.It shows how many listings come from each source, with OLX having the highest number.
#
# 2.It uses the source column and a count plot to count records.
#
# 3.We are showing which platforms contribute the most data to the dataset.

# %%
plt.figure(figsize=(6,4))
plt.scatter(df['year'], df['euro_price'])
plt.title('Year vs euro_Price')
plt.xlabel('Year')
plt.ylabel('euro_Price')
plt.show()

# %% [markdown]
# Insights
#
#
# 1.It shows how car prices change by year; newer cars generally have higher prices, with a few very high outliers.
#
# 2.It uses Year and euro_price in a scatter plot.
#
# 3.We are showing the relationship between car year and price.

# %%
year_price = df.groupby('year')['euro_price'].mean()

plt.figure(figsize=(6,4))
plt.plot(year_price)
plt.title('Average euro_Price by Year')
plt.xlabel('Year')
plt.ylabel('Average euro_Price')
plt.show()

# %% [markdown]
# Insights
#
#
# 1.It shows that the average car price increases over the years, with some ups and downs in recent years.
#
# 2.It uses Year and average euro_price in a line chart.
#
# 3.We are showing the trend of car prices over time.

# %%
plt.figure(figsize=(6,4))
df['source'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Source Percentage')
plt.ylabel('')
plt.show()

# %% [markdown]
# Insights
#
#
# 1.It shows the percentage share of listings from each source, with OLX contributing the majority.
#
# 2.It uses the source column and percentage values in a pie chart.
#
# 3.We are showing how the data is proportionally distributed across different platforms.

# %%
plt.figure(figsize=(6,4))
sns.violinplot(y=df['euro_price'])
plt.title('euro_Price Distribution (Violin Plot)')
plt.show()

# %% [markdown]
# Insights
#
#
# 1.It shows the distribution of euro prices, where most values are low and a few very high prices stretch the range.
#
# 2.It uses the euro_price column and a violin plot.
#
# 3.We are showing price density, spread, and extreme outliers in the data.

# %%
plt.figure(figsize=(8,6))
# Select only numeric columns for correlation calculation
sns.heatmap(df.select_dtypes(include=['number']).corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# 1.It shows how strongly numerical features are related to each other, with most having weak correlation.
#
# 2.It uses numerical columns (like year, km, power, euro_price) in a correlation heatmap.
#
# 3.We are showing relationships between variables and which features are related or independent.

# %% [markdown]
# ## Stage 4 – Documentation, Insights and Presentation
#
# Show a dashboard aligning all the charts in powerbi by connecting python in PowerBI
#
# Summarize findings in plain English (what do the patterns mean)
#
# Highlight 3–5 key insights (trends, anomalies, correlations)
#
# Provide recommendations for business or decision-making
#
# Explain the FINAL STORY WITH THE DASHBOARD/report
#
# Create a PDF pasting your DASHBOARD, explaining all the above mentioned concepts and submit it

# %% [markdown]
# https://docs.google.com/document/d/1bLx6DcIQCzN_QoHcZkCSClDj1VtXwxpo/edit?usp=sharing&ouid=115520377474591788454&rtpof=true&sd=true

# %% [markdown]
# *1.DESCRIPTIVE:*
#
#   The dataset contains 6,448 records of Mercedes-Benz E-Class cars, collected from online car listings. Each record represents one car advertisement.
# It includes information about the car details such as brand, model, year, fuel type, engine specifications, transmission, mileage, and price.
# The dataset also has location details like country, city, area, and zipcode, helping to understand regional price differences.
# Some columns store seller and advertisement information such as ad ID, source website, URL, and vehicle identification number (VIN), though VIN data is missing for many entries.
# There are a few unused or empty columns and some missing values, which means data cleaning is required before analysis.
# Overall, this dataset is useful for analyzing price trends, understanding how car features affect value, and supporting used car price prediction or market analysis.
#
# *2.DIGNOSIS:*
#
# The dataset contains missing values in some columns (such as VIN and a few specifications), which can affect analysis if not handled properly.
# There are irrelevant or empty columns (e.g., “Unnamed” fields) that should be removed during data cleaning.
# Some features like price, mileage, and engine power show wide variation, indicating the presence of outliers and strong influence on car value.
# Data needs pre_processing and normalization before using it for accurate price analysis or prediction models.
#
#
#
# 3.PREDICTIVE ANALYSIS: *italicized text*
# Use car features such as year, mileage, fuel type, engine power, transmission, and location to predict the price of a Mercedes-Benz E-Class car.
# Apply machine learning models (like Linear Regression, Decision Tree, or Random Forest) to estimate future or expected car prices.
# The prediction helps buyers get a fair price and sellers set competitive prices based on data-driven insights.
# Predictive analysis can also help identify the most important features that have the greatest impact on car price, improving pricing accuracy and decision-making.
#
# *4.PRESCRIPTIVE:*
#
# Suggest an optimal selling price range based on the predicted value and market trends.
# Recommend best buying or selling time by analyzing price patterns across years and locations.
# Advise sellers on which features to highlight or improve (low mileage, service history, condition) to increase car value.
# Help buyers choose the best-value car options by comparing predicted prices with listed prices.

# %% [markdown]
# Insights
#
# The dataset contains 6,448 used Mercedes-Benz E-Class car listings with details like year, mileage, fuel type, location, and price.
#
# Some columns have missing or unused data, so data cleaning is required before analysis
#
# Mileage and year have a strong effect on price—newer cars with lower mileage are more expensive.
#
# Missing values and outliers can affect accuracy, so preprocessing is necessary
#
# Car prices can be predicted using features such as year, mileage, fuel type, engine power, and location.
#
# Price prediction helps buyers find fair prices and sellers set competitive prices.
#
# Sellers should set prices based on predicted market value and highlight important features.
#
# Buyers should compare listed prices with predicted prices to get the best deal

# %% [markdown]
# # Future Enhancement
#
# 1.Add More Data
#
#      Include more recent car listings and data from more cities and countries.
#
#      This will improve accuracy and make price predictions more reliable.
#
# 2.Use Advanced Machine Learning Models
#
#      Apply models like Random Forest, XGBoost, or Neural Networks for better price prediction.
#
#      These models can handle complex patterns better than basic models.
#
# 3.Real-Time Price Prediction
#
#      Connect the system with live car listing websites to show real-time price estimates.
#
#      This helps users get updated market prices instantly.
#
# 4.Include More Car Features
#
#      Add details like car condition, accident history, service records, and ownership type.
#
#      This will give a more accurate and fair price estimate.
#
# 5.User-Friendly Web or Mobile App
#
#      Develop a simple web or mobile application where users can enter car details and get price predictions.
#
#      This makes the project useful for real users

# %% [markdown]
# # Conclusion
#
# From the analysis, we identified meaningful relationships and patterns in the dataset. The visualizations and insights highlight the main factors influencing the outcomes and provide a strong foundation for business decisions.
